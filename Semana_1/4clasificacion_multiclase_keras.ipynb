# %% [markdown]
# # Clasificación Multiclase en Keras

# %% [markdown]
# ## 1. Configuración Google Drive

# %%
ruta = 'https://raw.githubusercontent.com/cagomezv/AP_USA/refs/heads/main/Semana_1/Data/dataset_multiclase_Keras.csv'

# %% [markdown]
# ## 2. Lectura y visualización del set de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
tf.random.set_seed(23)
np.random.seed(12)

# %%
data = pd.read_csv(ruta)

# %%
data.head(10)
# Out:
#    x1  x2      y
# 0   8   8   alto
# 1   8   4   alto
# 2   3   8  medio
# 3   1   4   bajo
# 4   4   1   bajo
# 5   2   6  medio
# 6   6   6   alto
# 7   2   2   bajo
# 8   1   1   bajo
# 9   4   7  medio

# %%
data.shape
# Out:
# (13, 3)

# %%
X = data[['x1','x2']].to_numpy()
X.shape
# Out:
# (13, 2)

# %%
y_str = data['y'].to_numpy()
print(y_str.shape)
print(y_str)
# Out:
# (13,)
# ['alto' 'alto' 'medio' 'bajo' 'bajo' 'medio' 'alto' 'bajo' 'bajo' 'medio'
#  'medio' 'alto' 'alto']

# %%
idx_a = np.where(y_str=='alto') # Puntaje examen alto
idx_m = np.where(y_str=='medio') # Puntaje examen medio
idx_b = np.where(y_str=='bajo') # Puntaje examen bajo

plt.scatter(X[idx_a,0],X[idx_a,1],color='red',label='Puntaje examen alto')
plt.scatter(X[idx_m,0],X[idx_m,1],color='gray',label='Puntaje examen medio')
plt.scatter(X[idx_b,0],X[idx_b,1],color='magenta',label='Puntaje examen bajo')
plt.xlabel('$x_1$ (horas de sueño)')
plt.ylabel('$x_2$ (horas de estudio)')
plt.legend(bbox_to_anchor=(1.0,1.0),fontsize=8,edgecolor='black')
plt.show()

# %% [markdown]
# ## 3. Pre-procesamiento

# %%
# Convertir las etiquetas 'alto', 'medio' y 'bajo' a one-hot
# Hay tres formas de hacerlo: manual (no recomendado), con Scikit Learn
# (el más recomendado) o con Keras

# 1. Manual: texto -> entero -> one-hot

# Texto a entero
categorias = np.unique(y_str)
print(categorias)
text_to_int = dict((t, i) for i, t in enumerate(categorias))
print(text_to_int)

y_int = [text_to_int[texto] for texto in y_str]

for i, texto in enumerate(y_str):
  print(texto + '->   ' + str(y_int[i]))
# Out:
# ['alto' 'bajo' 'medio']
# {'alto': 0, 'bajo': 1, 'medio': 2}
# alto->   0
# alto->   0
# medio->   2
# bajo->   1
# bajo->   1
# medio->   2
# alto->   0
# bajo->   1
# bajo->   1
# medio->   2
# medio->   2
# alto->   0
# alto->   0

# %%
# Entero a one-hot
n = len(categorias)  # Número de categorías: 3 (alto, medio, bajo)
m = len(y_str)        # Cantidad de datos
y = np.zeros((m,n))

for row, value in enumerate(y_int):
  y[row,value] = 1

for i, texto in enumerate(y_str):
  print(texto + '->   ' + str(y_int[i]) + '->   ' + str(y[i,:]))
# Out:
# alto->   0->   [1. 0. 0.]
# alto->   0->   [1. 0. 0.]
# medio->   2->   [0. 0. 1.]
# bajo->   1->   [0. 1. 0.]
# bajo->   1->   [0. 1. 0.]
# medio->   2->   [0. 0. 1.]
# alto->   0->   [1. 0. 0.]
# bajo->   1->   [0. 1. 0.]
# bajo->   1->   [0. 1. 0.]
# medio->   2->   [0. 0. 1.]
# medio->   2->   [0. 0. 1.]
# alto->   0->   [1. 0. 0.]
# alto->   0->   [1. 0. 0.]

# %%
# 2. Con Scikit Learn: texto -> entero -> onehot
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# Codificar a entero
int_encoder = LabelEncoder()
y_int = int_encoder.fit_transform(y_str)

# Entero a one-hot
onehot_encoder = OneHotEncoder(sparse_output=False)    # No se requiere sparse porque son pocos datos
y_int = y_int.reshape(len(y_int), 1)
y = onehot_encoder.fit_transform(y_int)

for i, texto in enumerate(y_str):
  print(texto + '->   ' + str(y_int[i]) + '->   ' + str(y[i,:]))
# Out:
# alto->   [0]->   [1. 0. 0.]
# alto->   [0]->   [1. 0. 0.]
# medio->   [2]->   [0. 0. 1.]
# bajo->   [1]->   [0. 1. 0.]
# bajo->   [1]->   [0. 1. 0.]
# medio->   [2]->   [0. 0. 1.]
# alto->   [0]->   [1. 0. 0.]
# bajo->   [1]->   [0. 1. 0.]
# bajo->   [1]->   [0. 1. 0.]
# medio->   [2]->   [0. 0. 1.]
# medio->   [2]->   [0. 0. 1.]
# alto->   [0]->   [1. 0. 0.]
# alto->   [0]->   [1. 0. 0.]

# %%
# 3. Con Keras: texto -> entero -> one-hot
# texto -> entero: idéntico a scikit-learn
# entero -> one-hot: usando "to_categorical" de Keras

# Codificar a entero con Scikit-learn
int_encoder = LabelEncoder()
y_int = int_encoder.fit_transform(y_str)

# entero -> one-hot con Keras
from tensorflow.keras.utils import to_categorical
y = to_categorical(y_int)

for i, texto in enumerate(y_str):
  print(texto + '->   ' + str(y_int[i]) + '->   ' + str(y[i,:]))
# Out:
# alto->   0->   [1. 0. 0.]
# alto->   0->   [1. 0. 0.]
# medio->   2->   [0. 0. 1.]
# bajo->   1->   [0. 1. 0.]
# bajo->   1->   [0. 1. 0.]
# medio->   2->   [0. 0. 1.]
# alto->   0->   [1. 0. 0.]
# bajo->   1->   [0. 1. 0.]
# bajo->   1->   [0. 1. 0.]
# medio->   2->   [0. 0. 1.]
# medio->   2->   [0. 0. 1.]
# alto->   0->   [1. 0. 0.]
# alto->   0->   [1. 0. 0.]

# %% [markdown]
# ## 4. Crear el modelo en Keras

# %%
# Contenedor vacío
modelo = Sequential()

# %%
# Parámetros de entrada del modelo
dim_entrada = X.shape[1]    # Cada ejemplo de entrenamiento tendrá 2 características (x1,x2)
dim_salida = 3              # 3 posibles categorías

# Comenzar a llenar el modelo ('add')
modelo.add(Input(shape=(dim_entrada,)))
modelo.add(Dense(dim_salida, activation='softmax'))
# ¡Y listo, ya tenemos la estructura del clasificador!

# %%
# Información del modelo
modelo.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 5. Optimizador (Gradiente Descendente Estocástico) y pérdida

# %%
# Optimización: se usará gradiente descendente (SGD) con lr=0.2, función de error entropía
# cruzada (binary_crossentropy), métrica para el desempeño: accuracy (precisión)

optimizador = SGD(learning_rate=0.4)
modelo.compile(loss='categorical_crossentropy', optimizer=optimizador, metrics=['accuracy'])

# %% [markdown]
# ## 6. Entrenamiento y predicción

# %%
n_epochs = 130
s_minibatches = X.shape[0]  # Cada batch será del mismo tamaño del set de entrenamiento
historia = modelo.fit(X,y,epochs=n_epochs,batch_size=s_minibatches,verbose=1)
# Out:
# Epoch 1/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step - accuracy: 0.3077 - loss: 3.0506
# Epoch 2/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3846 - loss: 5.7527
# Epoch 3/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3077 - loss: 3.6475
# Epoch 4/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3846 - loss: 3.2281
# Epoch 5/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3077 - loss: 4.7163
# Epoch 6/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3846 - loss: 5.1803
# Epoch 7/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0
130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9231 - loss: 0.1758
# Epoch 84/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9231 - loss: 0.1745
# Epoch 85/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9231 - loss: 0.1732
# Epoch 86/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9231 - loss: 0.1720
# Epoch 87/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9231 - loss: 0.1708
# Epoch 88/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9231 - loss: 0.1696
# Epoch 89/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9231 - loss: 0.1684
# Epoch 90/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9231 - loss: 0.1672
# Epoch 91/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9231 - loss: 0.1661
# Epoch 92/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9231 - loss: 0.1650
# Epoch 93/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9231 - loss: 0.1638
# Epoch 94/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9231 - loss: 0.1627
# Epoch 95/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9231 - loss: 0.1617
# Epoch 96/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9231 - loss: 0.1606
# Epoch 97/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9231 - loss: 0.1596
# Epoch 98/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9231 - loss: 0.1585
# Epoch 99/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9231 - loss: 0.1575
# Epoch 100/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9231 - loss: 0.1565
# Epoch 101/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9231 - loss: 0.1555
# Epoch 102/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9231 - loss: 0.1545
# Epoch 103/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9231 - loss: 0.1536
# Epoch 104/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9231 - loss: 0.1526
# Epoch 105/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9231 - loss: 0.1517
# Epoch 106/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9231 - loss: 0.1508
# Epoch 107/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9231 - loss: 0.1499
# Epoch 108/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9231 - loss: 0.1490
# Epoch 109/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9231 - loss: 0.1481
# Epoch 110/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9231 - loss: 0.1472
# Epoch 111/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9231 - loss: 0.1463
# Epoch 112/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.1455
# Epoch 113/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1446
# Epoch 114/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.1438
# Epoch 115/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1430
# Epoch 116/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1422
# Epoch 117/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.1414
# Epoch 118/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.1406
# Epoch 119/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1398
# Epoch 120/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.1390
# Epoch 121/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1383
# Epoch 122/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.1375
# Epoch 123/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.1368
# Epoch 124/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.1360
# Epoch 125/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1353
# Epoch 126/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1346
# Epoch 127/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.1339
# Epoch 128/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.1332
# Epoch 129/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1325
# Epoch 130/130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.1318

# %% [markdown]
# ### 6.1 Comportamiento del error

# %%
plt.plot(historia.history['accuracy'])
plt.title('Precisión del modelo')
plt.ylabel('Precisión')
plt.xlabel('Épocas')
plt.show()

# %% [markdown]
# ### 6.2 Predicción

# %%
def dibujar_frontera(X,Y,modelo):
    # Valor mínimo y máximo y rellenado con ceros
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01

    # Grilla de puntos
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # Predecir categorías para cada punto en la grilla
    probabilidades = modelo.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = np.argmax(probabilidades,axis=1)   # Escoger la prob. más alta para cada predicción
    Z = Z.reshape(xx.shape)

    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Set1, alpha=0.8)

    idx_a = np.where(y_str=='alto') # Puntaje examen alto
    idx_m = np.where(y_str=='medio') # Puntaje examen medio
    idx_b = np.where(y_str=='bajo') # Puntaje examen bajo

    plt.scatter(X[idx_a,0],X[idx_a,1],color='red',label='Puntaje examen alto')
    plt.scatter(X[idx_m,0],X[idx_m,1],color='gray',label='Puntaje examen medio')
    plt.scatter(X[idx_b,0],X[idx_b,1],color='magenta',label='Puntaje examen bajo')
    plt.xlabel('$x_1$ (horas de sueño)')
    plt.ylabel('$x_2$ (horas de estudio)')
    plt.legend(bbox_to_anchor=(1.0,1.0),fontsize=8,edgecolor='black')

    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

dibujar_frontera(X,y_str,modelo)
# Out:
# 20000/20000 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step
